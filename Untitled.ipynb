# %% [markdown]
# This is second notebook where I try implement different aproach. The data has been cleaned from mission values.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_squared_log_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# Read the train data
data = pd.read_csv("data/house_price_train_no_missing_data.csv")
train_df = data.copy()
train_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
data2 = pd.read_csv("data/house_price_test_no_missing_data.csv")
test_df = data2.copy()
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0  1461          20       RH         80.0    11622   Pave      Reg
# 1  1462          20       RL         81.0    14267   Pave      IR1
# 2  1463          60       RL         74.0    13830   Pave      IR1
# 3  1464          60       RL         78.0     9978   Pave      IR1
# 4  1465         120       RL         43.0     5005   Pave      IR1
#
#   LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0         Lvl    AllPub    Inside  ...           0             0         0
# 1         Lvl    AllPub    Corner  ...          36             0         0
# 2         Lvl    AllPub    Inside  ...          34             0         0
# 3         Lvl    AllPub    Inside  ...          36             0         0
# 4         HLS    AllPub    Inside  ...          82             0         0
#
#   ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# Convert object into category
def to_category(df):
    for col in df.select_dtypes(["object"]):
        df[col] = df[col].astype("category")

# %%
to_category(train_df)

# %%
to_category(test_df)

# %%
train_df.shape, test_df.shape

# %%
# Combine two datasets and create dummies

# %%
test_to_combine = test_df.drop("Id", axis=1)
train_to_combine = train_df.drop("SalePrice", axis=1)

test_to_combine["train"] = 0
train_to_combine["train"] = 1

df_combined = pd.concat([train_to_combine, test_to_combine])

# %%
df_combined = pd.get_dummies(df_combined, drop_first=True)

# %%
train_df_prep = df_combined[df_combined["train"]==1]
test_df_prep = df_combined[df_combined["train"]==0]

train_df_prep = train_df_prep.drop("train", axis=1)
test_df_prep = test_df_prep.drop("train", axis=1)

# %%
train_df_prep.shape, test_df_prep.shape

# %%
# Split data into X & y
X = train_df_prep
y = np.log1p(train_df["SalePrice"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2)

# %%
base_model = GradientBoostingRegressor(random_state=45)

base_model.fit(X_train, y_train)

y_pred = base_model.predict(X_test)

score = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred))

print(f"R-Squared: {score}")
print(f"RMSE: {rmse}")
print(f"RMSLE: {rmsle}")

# %%
base_model.get_params

# %% [markdown]
# ####  Let's make prediction and see where we end up on leaderboard

# %%
new_test = test_df_prep

predictions = base_model.predict(new_test)
np.expm1(predictions)

# %%
# # Submit predictions
# submission = pd.DataFrame()
# submission["Id"] = test_df["Id"]
# submission["SalePrice"] = np.exp(predictions)
# submission.to_csv("submissions/submission2.csv", index=False)

# %%
# Let' see if we can improve our model
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GradientBoostingRegressor(random_state=45)

# %%
gbr_param = {"loss": ["ls", "lad", "huber"],
             'n_estimators':[100,300,800], 
             'learning_rate': [0.1, 0.05, 0.01], 
             'max_depth':[3,4,6],
             'min_samples_leaf':[3,5,9], 
             'max_features':["auto","sqrt","log2"]}

grid_search = GridSearchCV(grid_model,
                           param_grid=gbr_param,
                           n_jobs=-1,
                           verbose=1, 
                           cv=3)
grid_search.fit(X_train, y_train)

# %%
grid_search.best_score_

# %%
grid_search.best_params_

# %%
model1 = GradientBoostingRegressor(loss="huber",
                                   learning_rate=0.05,
                                   max_depth=3,
                                   max_features="sqrt",
                                   min_samples_leaf=9,
                                   n_estimators=800,
                                   random_state=45)

model1.fit(X_train, y_train)

y_pred1 = model1.predict(X_test)

score1 = r2_score(y_test, y_pred1)
rmse1 = np.sqrt(mean_squared_error(y_test, y_pred1))
rmsle1 = np.sqrt(mean_squared_log_error(y_test, y_pred1))

print(f"R-Squared: {score1}")
print(f"RMSE: {rmse1}")
print(f"RMSLE: {rmsle1}")

# %%
# Print model scores
models = pd.DataFrame({
    "Models": ["GradientBoost Base",
               "GradientBoost Best"],
    "R-Squared":[score, score1],
    "RMSE": [rmse, rmse1],
    "RMSLE": [rmsle, rmsle1]
})

models.sort_values(by="RMSLE", ascending=False).T

# %%
test2 = test_df_prep

predictions2 = model1.predict(test2)
np.expm1(predictions2)

# %% [markdown]
# ## Let's try if reducing features can improve model

# %%
def feature_importance(model, data):
    """
    Function creates table of models features importance.
    """
    fea_imp = pd.DataFrame({"col": data.columns,
                            "imp": model.feature_importances_})
    fea_imp = fea_imp.sort_values(by="imp",
                                  ascending=False).iloc[:]
    return fea_imp

# %%
feat_imp_df = feature_importance(model1, X_train)
feat_imp_df.iloc[:50]

# %%
from sklearn.feature_selection import RFE

# %%
# Select 50 features to train a model
rfe = RFE(model1,n_features_to_select=80, step=1)

rfe.fit(X, y)

# %%
X_train_rfe = rfe.transform(X_train)
X_test_rfe = rfe.transform(X_test)

model1 = GradientBoostingRegressor(loss="huber",
                                   learning_rate=0.05,
                                   max_depth=3,
                                   max_features="sqrt",
                                   min_samples_leaf=9,
                                   n_estimators=800,
                                   random_state=45)

model1.fit(X_train_rfe, y_train)

y_pred1 = model1.predict(X_test_rfe)

score1 = r2_score(y_test, y_pred1)
rmse1 = np.sqrt(mean_squared_error(y_test, y_pred1))
rmsle1 = np.sqrt(mean_squared_log_error(y_test, y_pred1))

print(f"R-Squared: {score1}")
print(f"RMSE: {rmse1}")
print(f"RMSLE: {rmsle1}")

# %% [markdown]
# Model has improved a little bit. Let's have a look on these features

# %%
columns = list(X.columns)
ranking = rfe.ranking_
rfe_selected = pd.DataFrame()
rfe_selected = pd.concat([pd.DataFrame(columns),
                          pd.DataFrame(ranking)],
                         axis=1)
rfe_selected.columns = ["Feature name","Rankings"]
rfe_selected.sort_values(by="Rankings", ascending=False)

# %%
# # Make predictions for submission on Test dataset
# X_pred = rfe.transform(test2)
# predictions2 = model1.predict(X_pred)

# # Submit predictions
# submission2 = pd.DataFrame()
# submission2["Id"] = test_df["Id"]
# submission2["SalePrice"] = np.exp(predictions2)
# submission2.to_csv("submissions/submission4.csv", index=False)

# %% [markdown]
# **Now I will scale using MinMaxScaler()**
#
# **Question:** Do I have to scale my dependent variable?
# https://stackoverflow.com/questions/46257726/do-i-need-to-scale-test-data-and-dependent-variable-in-the-train-data

# %%
# Split data into X & y
X = train_df_prep
y = np.log1p(train_df["SalePrice"])
test_df2 = test_df_prep

# %%
test_df2.shape, X.shape

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=45)

# Transform training dataset
scaler = MinMaxScaler().fit(X_train)
scaled_X_train = scaler.transform(X_train)

# Transform validation dataset
scaled_X_test = scaler.transform(X_test)

# %%
# Instantiate new model with scaled data
scaled_gbr_model = GradientBoostingRegressor(random_state=45)

# Fit the data
scaled_gbr_model.fit(scaled_X_train, y_train)
# Make predictions
y_pred_s = scaled_gbr_model.predict(scaled_X_test)

# # Evaluate model
score_scaled = scaled_gbr_model.score(scaled_X_test, y_test)
rmse_scaled = np.sqrt(mean_squared_error(y_test, y_pred_s))
rmsle_scaled = np.sqrt(mean_squared_log_error(y_test, y_pred_s))

print(f"R-Squared: {score_scaled}")
print(f"RMSE: {rmse_scaled}")
print(f"RMSLE: {rmsle_scaled}")

# %%
# Improve model for scaled model
gbr_param = {"loss": ["ls", "lad", "huber"],
             'n_estimators':[100,300,800], 
             'learning_rate': [0.1, 0.05, 0.01], 
             'max_depth':[3,4,6],
             'min_samples_leaf':[3,5,9], 
             'max_features':["auto","sqrt","log2"]}

grid_search2 = GridSearchCV(scaled_gbr_model,
                           param_grid=gbr_param,
                           n_jobs=-1,
                           verbose=1, 
                           cv=3)
grid_search2.fit(X_train, y_train)

# %%
grid_search2.best_score_

# %%
grid_search2.best_params_

# %%
best_scaled_model = GradientBoostingRegressor(learning_rate=0.05,
                                              loss="lad",
                                              max_depth=6,
                                              max_features="sqrt",
                                              min_samples_leaf=5,
                                              n_estimators=800,
                                              random_state=45)

# Fit the model
best_scaled_model.fit(scaled_X_train, y_train)
# Make predictions
scaled_y_pred = best_scaled_model.predict(scaled_X_test)

# Evaluate model
score_scaled = best_scaled_model.score(scaled_X_test, y_test)
rmse_scaled = np.sqrt(mean_squared_error(y_test, scaled_y_pred))
rmsle_scaled = np.sqrt(mean_squared_log_error(y_test, scaled_y_pred))

print(f"R-Squared: {score_scaled}")
print(f"RMSE: {rmse_scaled}")
print(f"RMSLE: {rmsle_scaled}")

# %% [markdown]
# Looks like this approach didn't make much difference, unless I am doing something wrong. Need more reading!!.

# %% [markdown]
# **Using StandardScaler()**

# %%
# Split data into X & y
X = train_df_prep
y = np.log1p(train_df["SalePrice"])
test_df3 = test_df_prep

# %%
rfe1 = RFE(GradientBoostingRegressor(),
           n_features_to_select=80,
           step=1)
rfe1.fit(X,y)

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=45)

# Transform training dataset
scaler = StandardScaler().fit(X_train)
scaled_X_train = scaler.transform(X_train)
rfe_X_train = rfe.transform(scaled_X_train)

# Transform validation dataset
scaled_X_test = scaler.transform(X_test)
rfe_X_test = rfe.transform(scaled_X_test)

# %%
rfe_model2 = GradientBoostingRegressor(learning_rate=0.05,
                                              loss="lad",
                                              max_depth=6,
                                              max_features="sqrt",
                                              min_samples_leaf=5,
                                              n_estimators=800,
                                              random_state=45)

# Fit the mode
rfe_model2.fit(rfe_X_train, y_train)
# Make predictions
rfe_y_pred = rfe_model2.predict(rfe_X_test)

# Evaluate model
score_rfe = rfe_model2.score(rfe_X_test, y_test)
rmse_rfe = np.sqrt(mean_squared_error(y_test, rfe_y_pred))
rmsle_rfe = np.sqrt(mean_squared_log_error(y_test, rfe_y_pred))

print(f"R-Squared: {score_rfe}")
print(f"RMSE: {rmse_rfe}")
print(f"RMSLE: {rmsle_rfe}")

# %%
model3 = GradientBoostingRegressor(random_state=45)

# %%
# Improve model for scaled model
gbr_param = {"loss": ["ls", "lad", "huber"],
             'n_estimators':[100,300,800], 
             'learning_rate': [0.1, 0.05, 0.01], 
             'max_depth':[3,4,6],
             'min_samples_leaf':[3,5,9], 
             'max_features':["auto","sqrt","log2"]}

grid_search3 = GridSearchCV(model3,
                           param_grid=gbr_param,
                           n_jobs=-1,
                           verbose=1, 
                           cv=3)
grid_search3.fit(rfe_X_train, y_train)

# %%
grid_search3.best_score_

# %%
grid_search3.best_params_

# %%
rfe_model3 = GradientBoostingRegressor(learning_rate=0.05,
                                              loss="huber",
                                              max_depth=4,
                                              max_features="sqrt",
                                              min_samples_leaf=3,
                                              n_estimators=800,
                                              random_state=45)

# Fit the model
rfe_model3.fit(rfe_X_train, y_train)
# Make predictions
rfe_y_pred2 = rfe_model3.predict(rfe_X_test)

# Evaluate model
score_rfe2 = rfe_model3.score(rfe_X_test, y_test)
rmse_rfe2 = np.sqrt(mean_squared_error(y_test, rfe_y_pred2))
rmsle_rfe2 = np.sqrt(mean_squared_log_error(y_test, rfe_y_pred2))

print(f"R-Squared: {score_rfe2}")
print(f"RMSE: {rmse_rfe2}")
print(f"RMSLE: {rmsle_rfe2}")

# %% [markdown]
# # Another attempt to get better score on Kaggle leaderboard by practicing different ideas and techniques

# %%
pd.describe_option('columns')
# Out:
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 20] [currently: 20]
# display.max_info_columns : int
#     max_info_columns is used in DataFrame.info method to decide if
#     per column information will be printed.
#     [default: 100] [currently: 100]

# %%
pd.set_option('display.max_columns', None)

# %%
# Read the train data
data = pd.read_csv("data/house_price_train_no_missing_data.csv")
train_df = data.copy()
train_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
data2 = pd.read_csv("data/house_price_test_no_missing_data.csv")
test_df = data2.copy()
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0  1461          20       RH         80.0    11622   Pave      Reg
# 1  1462          20       RL         81.0    14267   Pave      IR1
# 2  1463          60       RL         74.0    13830   Pave      IR1
# 3  1464          60       RL         78.0     9978   Pave      IR1
# 4  1465         120       RL         43.0     5005   Pave      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# ...

# %%
nominal_list = train_df.dtypes[train_df.dtypes=="O"].index

# %%
nominal_list
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
nominal_df = train_df[nominal_list].copy()
nominal_df["Exterior1st"].value_counts()   # .count()
# Out:
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# BrkComm      2
# Stone        2
# ImStucc      1
# CBlock       1
# AsphShn      1
# Name: Exterior1st, dtype: int64

# %%
nominal_df["Exterior2nd"].value_counts()
# Out:
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# Other        1
# CBlock       1
# Name: Exterior2nd, dtype: int64

# %%
nominal_df.Condition1.value_counts()
# Out:
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64

# %%
nominal_df.Condition2.value_counts()
# Out:
# Norm      1445
# Feedr        6
# PosN         2
# RRNn         2
# Artery       2
# PosA         1
# RRAn         1
# RRAe         1
# Name: Condition2, dtype: int64

# %%
nominal_df.ExterCond.value_counts()
# Out:
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64

# %%
nominal_df.ExterQual.value_counts()
# Out:
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: ExterQual, dtype: int64

# %% [markdown]
# Looks like some nominal columns have same information. Few questions:
# 1. What to do with columns containing similar data( delete on of them or add them up)?
# 2. How to make this process automatic?
# 3. If I drop columns containing similar information will it improve model?

# %%
col_to_drop = ["ExterCond","Condition2","Exterior2nd"]
for col in col_to_drop:
    train_df.drop([col], axis=1, inplace=True)
    test_df.drop([col], axis=1, inplace=True)

# %%
discrete = []
for col in train_df.columns:
    if train_df[col].dtypes !="O" and len(train_df[col].unique()) <= 16:
        discrete.append(col)

# %%
train_df[discrete]
# Out:
#       MSSubClass  OverallQual  OverallCond  BsmtFullBath  BsmtHalfBath  \
# 0             60            7            5             1             0
# 1             20            6            8             0             1
# 2             60            7            5             1             0
# 3             70            7            5             1             0
# 4             60            8            5             1             0
# ...          ...          ...          ...           ...           ...
# 1455          60            6            5             0             0
# 1456          20            6            6             1             0
# 1457          70            7            9             0             0
# 1458          20            5            6             1             0
# 1459          20            5            6             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  Fireplaces  GarageCars  \
# ...

# %%
# Change PoolArea into binary 0, 1
train_df["PoolArea"].value_counts()
# Out:
# 0      1453
# 738       1
# 648       1
# 576       1
# 555       1
# 519       1
# 512       1
# 480       1
# Name: PoolArea, dtype: int64

# %%
train_df["PoolArea"] = train_df["PoolArea"].apply(lambda x: 0 if x==0 else 1)
test_df["PoolArea"] = test_df["PoolArea"].apply(lambda x: 0 if x==0 else 1)

# %%
numeric = []
for col in train_df.columns:
    if train_df[col].dtypes!="O" and col not in discrete:
        numeric.append(col)
        
numeric_df = train_df[numeric].copy()

# %%
num_list = numeric_df.columns.tolist()

# %%
numeric_df.drop(["YearBuilt", "YearRemodAdd"], axis=1, inplace=True)

# %%
# Need to change YearBuild and YearRemondAdd into categorical
ls = ["YearBuilt", "YearRemodAdd"]
for col in ls:
    train_df[col] = train_df[col].astype("category")
    test_df[col] = test_df[col].astype("category")

# %%
train_df.dtypes[train_df.dtypes=="O"].index
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'BldgType',
#        'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'MasVnrType',
#        'ExterQual', 'Foundation', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', 'KitchenQual', 'Functional', 'PavedDrive', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
def convert_to_cat(df):
    for col in df.dtypes[df.dtypes=="O"].index:
        df[col] = df[col].astype("category")
        
convert_to_cat(train_df)
convert_to_cat(test_df)

# %%
for col in discrete:
    train_df[col] = train_df[col].astype("category")
    test_df[col] = test_df[col].astype("category")

# %%
train_df[num_list]
# Out:
#       LotFrontage  LotArea YearBuilt YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0            65.0     8450      2003         2003       196.0         706
# 1            80.0     9600      1976         1976         0.0         978
# 2            68.0    11250      2001         2002       162.0         486
# 3            60.0     9550      1915         1970         0.0         216
# 4            84.0    14260      2000         2000       350.0         655
# ...           ...      ...       ...          ...         ...         ...
# 1455         62.0     7917      1999         2000         0.0           0
# 1456         85.0    13175      1978         1988       119.0         790
# 1457         66.0     9042      1941         2006         0.0         275
# 1458         68.0     9717      1950         1996         0.0          49
# 1459         75.0     9937      1965         1965         0.0         830
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# ...

# %%
train_df.LotArea.plot(kind="hist")

# %%
log = np.log1p(train_df.LotArea)
plt.hist(log);
